# %% [markdown]
# This site uses data downloaded from the ILAMB CMIP6 site to figure out the types of bias that exist in the Eastern Amazon across the existing CMIP6 land model archive

# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import xarray as xr
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
import datetime
import netCDF4 as nc4

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 6):
    ax = fig.add_subplot(2, 3, i)
    dat = 'GPCP2'
    var = 'rainfall'
    filename =root + var + '/' + dat + '_' + models[i] + '.nc'
    rainfall = xr.open_dataset(filename,group='MeanState')
    rainfall.bias_map_of_pr.sel(lat_=slice(-20, 0),lon_=slice(-100, 0)).plot(vmin=-3, vmax=3)

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 6):
    ax = fig.add_subplot(2, 3, i)
    dat = 'GPCP2'
    var = 'rainfall'
    filename =root + var + '/' + dat + '_' + models[i] + '.nc'
    rainfall = xr.open_dataset(filename,group='MeanState')
    rain=rainfall.timeint_of_pr.sel(lat=slice(-20, 0),lon=slice(-100, 0))
    rain=rain*365
    rain.plot(vmin=0, vmax=4000)

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 6):
    ax = fig.add_subplot(2, 3, i)
    dat = 'GEOCARBON'
    var = 'biomass'    
    filename =root + var + '/' + dat + '_' + models[i] + '.nc'
    print(filename)
    biomass = xr.open_dataset(filename,group='MeanState')
    biomass=biomass.bias_map_of_biomass.sel(lat_=slice(-20, 0),lon_=slice(-90, -25))
    biomass.plot(vmin=-20, vmax=10)
# Out:
# /glade/u/home/rfisher/ILAMB_output/biomass/GEOCARBON_CESM2.nc
# /glade/u/home/rfisher/ILAMB_output/biomass/GEOCARBON_SAM0-UNICON.nc
# /glade/u/home/rfisher/ILAMB_output/biomass/GEOCARBON_IPSL-CM6A-LR.nc
# /glade/u/home/rfisher/ILAMB_output/biomass/GEOCARBON_BCC-ESM1.nc
# /glade/u/home/rfisher/ILAMB_output/biomass/GEOCARBON_EC-Earth3-Veg.nc

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 6):
    ax = fig.add_subplot(2, 3, i)
    dat = 'GEOCARBON'
    var = 'biomass'    
    filename =root + var + '/' + dat + '_' + models[i] + '.nc'
    print(filename)
    gpp = xr.open_dataset(filename,group='MeanState')
    gpp=biomass.bias_map_of_biomass.sel(lat_=slice(-20, 0),lon_=slice(-90, -25))
    biomass.plot(vmin=-20, vmax=10)

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 6):
    ax = fig.add_subplot(2, 3, i)
    dat = 'GEOCARBON'
    var = 'biomass'    
    filename =root + var + '/' + dat + '_' + models[i] + '.nc'
    print(filename)
    biomass = xr.open_dataset(filename,group='MeanState')
    biomass=biomass.timeint_of_biomass.sel(lat=slice(-20, 0),lon=slice(-90, -25))
    biomass.plot(vmin=0, vmax=30)

# %%
models = ['Benchmark','CESM2','SAM0-UNICON','IPSL-CM6A-LR','BCC-ESM1','EC-Earth3-Veg']
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 6):
    ax = fig.add_subplot(2, 3, i)
    dat = 'GBAF'
    var = 'gpp'    
    filename =root + var + '/' + dat + '_' + models[i] + '.nc'
    gpp = xr.open_dataset(filename,group='MeanState')
    print(filename)
    gpp = xr.open_dataset(filename,group='MeanState')
    gpp=gpp.bias_map_of_gpp.sel(lat_=slice(-20, 0),lon_=slice(-90, -25))
    gpp=gpp*365
    gpp.plot(vmin=-1000, vmax=1000)
# Out:
# /glade/u/home/rfisher/ILAMB_output/gpp/GBAF_CESM2.nc
# /glade/u/home/rfisher/ILAMB_output/gpp/GBAF_SAM0-UNICON.nc
# /glade/u/home/rfisher/ILAMB_output/gpp/GBAF_IPSL-CM6A-LR.nc
# /glade/u/home/rfisher/ILAMB_output/gpp/GBAF_BCC-ESM1.nc
# /glade/u/home/rfisher/ILAMB_output/gpp/GBAF_EC-Earth3-Veg.nc

# %%
models = ['Benchmark','CESM2','SAM0-UNICON','IPSL-CM6A-LR','BCC-ESM1','EC-Earth3-Veg']
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 6):
    ax = fig.add_subplot(2, 3, i)
    dat = 'GBAF'
    var = 'evapfrac'    
    filename =root + var + '/' + dat + '_' + models[i] + '.nc'
    evapfrac = xr.open_dataset(filename,group='MeanState')
    print(filename)
    evapfrac = xr.open_dataset(filename,group='MeanState')
    evapfrac=evapfrac.bias_map_of_EvapFrac.sel(lat_=slice(-20, 0),lon_=slice(-90, -25))
    evapfrac.plot(vmin=-0.2, vmax=0.3)
# Out:
# /glade/u/home/rfisher/ILAMB_output/evapfrac/GBAF_CESM2.nc
# /glade/u/home/rfisher/ILAMB_output/evapfrac/GBAF_SAM0-UNICON.nc
# /glade/u/home/rfisher/ILAMB_output/evapfrac/GBAF_IPSL-CM6A-LR.nc
# /glade/u/home/rfisher/ILAMB_output/evapfrac/GBAF_BCC-ESM1.nc
# /glade/u/home/rfisher/ILAMB_output/evapfrac/GBAF_EC-Earth3-Veg.nc

# %% [markdown]
# Load biomass data

# %% [markdown]
# Load Biomass model output

# %%
models = ['Benchmark','CESM2','SAM0-UNICON','IPSL-CM6A-LR','BCC-CSM2-MR','EC-Earth3-Veg']
root ='/glade/u/home/rfisher/ILAMB_output/'
sz=6
    
clims=range(1, 6)
for c in clims:
   dat = 'GEOCARBON'
   var = 'biomass'    
   filename =root + var + '/' + dat + '_' + models[c] + '.nc'
   biomass = xr.open_dataset(filename,group='MeanState')
   dat = 'GPCP2'
   var = 'rainfall'
   filename =root + var + '/' + dat + '_' + models[c] + '.nc'
   rainfall = xr.open_dataset(filename,group='MeanState')
   x=rainfall.timeint_of_pr.sel(lat=slice(-20, 0),lon=slice(-100, 0))
   y=biomass.timeint_of_biomass.sel(lat=slice(-20, 0),lon=slice(-100, 0))
   if x.sizes['lon'] != y.sizes['lon']:
      lns=range(0,x.sizes['lon'])
      y=y.isel(lon=lns)
   x=x*365
   plt.scatter(x,y,s=sz)
   plt.ylim(0,50)
   plt.xlim(0,5000)
   plt.title('rain vs biomass')

# %%
models = ['Benchmark','CESM2','SAM0-UNICON','IPSL-CM6A-LR','BCC-ESM1','EC-Earth3-Veg']
root ='/glade/u/home/rfisher/ILAMB_output/'
sz=6
    
clims=range(1, 6)
for c in clims:
   dat = 'GBAF'
   var = 'gpp'    
   filename =root + var + '/' + dat + '_' + models[c] + '.nc'
   gpp = xr.open_dataset(filename,group='MeanState')
   dat = 'GPCP2'
   var = 'rainfall'
   filename =root + var + '/' + dat + '_' + models[c] + '.nc'
   rainfall = xr.open_dataset(filename,group='MeanState')
   x=rainfall.timeint_of_pr.sel(lat=slice(-20, 0),lon=slice(-100, 0))
   y=gpp.timeint_of_gpp.sel(lat=slice(-20, 0),lon=slice(-100, 0))
   if x.sizes['lon'] != y.sizes['lon']:
      lns=range(0,x.sizes['lon'])
      y=y.isel(lon=lns)
   y=y*365
   x=x*365
   plt.scatter(x,y,s=sz)
   plt.ylim(0,6000)
   plt.xlim(0,5000)
   plt.title('rain vs gpp')

# %% [markdown]
# Load Rainfall data

# %%
models = ['Benchmark','CESM2','SAM0-UNICON','IPSL-CM6A-LR','BCC-ESM1','EC-Earth3-Veg']
root ='/glade/u/home/rfisher/ILAMB_output/'
sz=6
    
clims=range(1, 6)
for c in clims:
   dat = 'GBAF'
   var = 'gpp'    
   filename =root + var + '/' + dat + '_' + models[c] + '.nc'
   gpp = xr.open_dataset(filename,group='MeanState')
   dat = 'GEOCARBON'
   var = 'biomass'
   filename =root + var + '/' + dat + '_' + models[c] + '.nc'
   biomass = xr.open_dataset(filename,group='MeanState')
   x=gpp.timeint_of_gpp.sel(lat=slice(-20, 0),lon=slice(-100, 0))
   y=biomass.timeint_of_biomass.sel(lat=slice(-20, 0),lon=slice(-100, 0))
   if x.sizes['lon'] != y.sizes['lon']:
      lns=range(0,x.sizes['lon'])
      y=y.isel(lon=lns)
   
   x=x*365
   plt.scatter(x,y,s=sz)
   plt.ylim(0,50)
   plt.xlim(0,5000)
   plt.title('gpp vs biomass')

# %%
models = ['Benchmark','CESM2','SAM0-UNICON','IPSL-CM6A-LR','BCC-ESM1','EC-Earth3-Veg']
root ='/glade/u/home/rfisher/ILAMB_output/'
sz=6
    
clims=range(1, 6)
for c in clims:
   
  
   dat = 'GPCP2'
   var = 'rainfall'
   filename =root + var + '/' + dat + '_' + models[c] + '.nc'
   rainfall = xr.open_dataset(filename,group='MeanState')
   x=rainfall.timeint_of_pr.sel(lat=slice(-20, 0),lon=slice(-100, 0)) 

   dat = 'GBAF'
   var = 'evapfrac'
   filename =root + var + '/' + dat + '_' + models[c] + '.nc'
   ef = xr.open_dataset(filename,group='MeanState')
   y=ef.timeint_of_EvapFrac.sel(lat=slice(-20, 0),lon=slice(-100, 0))

  
   if x.sizes['lon'] != y.sizes['lon']:
      lns=range(0,x.sizes['lon'])
      y=y.isel(lon=lns)
   
   x=x*365
   plt.scatter(x,y,s=sz)
   plt.ylim(0,1)
   plt.xlim(0,5000)
   plt.title('rain vs ef')

# %%
models = ['Benchmark','CESM2','SAM0-UNICON','IPSL-CM6A-LR','BCC-ESM1','EC-Earth3-Veg']
root ='/glade/u/home/rfisher/ILAMB_output/'
sz=6
    
clims=range(1, 6)
for c in clims:
   
  
   dat = 'GPCP2'
   var = 'rainfall'
   filename =root + var + '/' + dat + '_' + models[c] + '.nc'
   rainfall = xr.open_dataset(filename,group='MeanState')
   x=rainfall.timeint_of_pr.sel(lat=slice(-20, 0),lon=slice(-100, 0)) 

   dat = 'GLEAM'
   var = 'et'    
   filename =root + var + '/' + dat + '_' + models[c] + '.nc'
   et = xr.open_dataset(filename,group='MeanState')
   y=et.timeint_of_et.sel(lat=slice(-20, 0),lon=slice(-100, 0))
 
   if x.sizes['lon'] != y.sizes['lon']:
      lns=range(0,x.sizes['lon'])
      y=y.isel(lon=lns)
   y=y*365
   x=x*365
   plt.scatter(x,y,s=sz)
   plt.ylim(0,3000)
   plt.xlim(0,5000)
   plt.title('rain vs et')

# %%
models = ['Benchmark','CESM2','SAM0-UNICON','IPSL-CM6A-LR','BCC-ESM1','EC-Earth3-Veg']
root ='/glade/u/home/rfisher/ILAMB_output/'
sz=6
    
clims=range(2,3)
for c in clims:
    
   dat = 'GEOCARBON'
   var = 'biomass'
   filename =root + var + '/' + dat + '_' + models[c] + '.nc'
   biomass = xr.open_dataset(filename,group='MeanState')
   print(biomass)
   y=biomass.timeint_of_biomass.sel(lat=slice(-20, 0),lon=slice(-100, 0))
   y.plot()
   print(biomass.timeint_of_biomass)
   bias=biomass.bias_map_of_biomass
   print(bias.sizes())
# Out:
# <xarray.Dataset>
# Dimensions:                   (lat: 192, lat_: 550, lon: 288, lon_: 1008, nb: 2)
# Coordinates:
#   * lat                       (lat) float64 -90.0 -89.06 -88.12 ... 89.06 90.0
#   * lon                       (lon) float64 -178.8 -177.5 -176.2 ... 178.8 180.0
#   * lat_                      (lat_) float64 -89.76 -89.51 ... 89.51 89.76
#   * lon_                      (lon_) float64 -179.8 -179.4 ... 179.4 179.8
# Dimensions without coordinates: nb
# Data variables:
#     lat_bnds                  (lat, nb) float64 ...
#     lon_bnds                  (lon, nb) float64 ...
#     timeint_of_biomass        (lat, lon) float64 ...
#     lat_bnds_                 (lat_, nb) float64 ...
#     lon_bnds_                 (lon_, nb) float64 ...
#     bias_map_of_biomass       (lat_, lon_) float64 ...
#     biasscore_map_of_biomass  (lat_, lon_) float64 ...
# <xarray.DataArray 'timeint_of_biomass' (lat: 192, lon: 288)>
# array([[0.00000e+00, 0.00000e+00, 0.00000e+00, ..., 0.00000e+00, 0.00000e+00,
#         0.00000e+00],
#        [0.00000e+00, 0.00000e+00, 0.00000e+00, ..., 0.00000e+00, 0.00000e+00,
#         0.00000e+00],
#        [0.00000e+00, 0.00000e+00, 0.00000e+00, ..., 0.00000e+00, 0.00000e+00,
#         0.00000e+00],
#        ...,
#        [9.96921e+36, 9.96921e+36, 9.96921e+36, ..., 9.96921e+36, 9.96921e+36,
#         9.96921e+36],
#        [9.96921e+36, 9.96921e+36, 9.96921e+36, ..., 9.96921e+36, 9.96921e+36,
#         9.96921e+36],
#        [9.96921e+36, 9.96921e+36, 9.96921e+36, ..., 9.96921e+36, 9.96921e+36,
#         9.96921e+36]])
# Coordinates:
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 -178.8 -177.5 -176.2 -175.0 ... 177.5 178.8 180.0
# Attributes:
#     units:    kg m-2
#     min:      0.0
#     dn99:     0.0
#     up99:     38.26037516575636
#     max:      51.57721362179273
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-cd12898551b9> in <module>
#      16    print(biomass.timeint_of_biomass)
#      17    bias=biomass.bias_map_of_biomass
# ---> 18    print(bias.sizes())
#
# TypeError: 'Frozen' object is not callable
